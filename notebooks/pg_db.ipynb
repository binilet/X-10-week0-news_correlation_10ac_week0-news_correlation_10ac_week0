# %%
# !pip install psycopg2
# Out:
# Collecting psycopg2
#   Downloading psycopg2-2.9.9-cp311-cp311-win_amd64.whl.metadata (4.5 kB)
# Downloading psycopg2-2.9.9-cp311-cp311-win_amd64.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    - -------------------------------------- 0.0/1.2 MB 991.0 kB/s eta 0:00:02
#    --------- ------------------------------ 0.3/1.2 MB 3.3 MB/s eta 0:00:01
#    --------- ------------------------------ 0.3/1.2 MB 3.3 MB/s eta 0:00:01
#    --------- ------------------------------ 0.3/1.2 MB 3.3 MB/s eta 0:00:01
#    --------------- ------------------------ 0.5/1.2 MB 1.9 MB/s eta 0:00:01
#    --------------------- ------------------ 0.6/1.2 MB 2.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 0.9/1.2 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------  1.1/1.2 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  1.2/1.2 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------  1.2/1.2 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------  1.2/1.2 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------  1.2/1.2 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------  1.2/1.2 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------  1.2/1.2 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------  1.2/1.2 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------  1.2/1.2 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------  1.2/1.2 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------  1.2/1.2 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------  1.2/1.2 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------  1.2/1.2 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------  1.2/1.2 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------  1.2/1.2 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------  1.2/1.2 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------  1.2/1.2 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 911.7 kB/s eta 0:00:00
# Installing collected packages: psycopg2
# Successfully installed psycopg2-2.9.9

# %%
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker
import pandas as pd
import psycopg2

import sys, os
if os.path.abspath("..") not in sys.path:
    sys.path.insert(0, os.path.abspath(".."))

from src.db_schema import Base, Article, TrafficData, DomainLocation

connection = psycopg2.connect(
    dbname="week_0",
    user="postgres",
    password="123",
    host="localhost",
    port="5433"
)

cur = connection.cursor()
engine = create_engine('postgresql+psycopg2://postgres:123@localhost:5433/week_0')

# Create all tables defined in db_schema.py
Base.metadata.create_all(engine)
connection.commit()
cur.close()
connection.close()
# Out:
# ---------------------------------------------------------------------------
# InvalidForeignKey                         Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1969, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1968     if not evt_handled:
# -> 1969         self.dialect.do_execute(
#    1970             cursor, str_statement, effective_parameters, context
#    1971         )
#    1973 if self._has_events or self.engine._has_events:
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py:922, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     921 def do_execute(self, cursor, statement, parameters, context=None):
# --> 922     cursor.execute(statement, parameters)
#
# InvalidForeignKey: there is no unique constraint matching given keys for referenced table "traffic_data"
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[6], line 24
#      21 engine = create_engine('postgresql+psycopg2://postgres:123@localhost:5433/week_0')
#      23 # Create all tables defined in db_schema.py
# ---> 24 Base.metadata.create_all(engine)
#      25 connection.commit()
#      26 cur.close()
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\sql\schema.py:5832, in MetaData.create_all(self, bind, tables, checkfirst)
#    5808 def create_all(
#    5809     self,
#    5810     bind: _CreateDropBind,
#    5811     tables: Optional[_typing_Sequence[Table]] = None,
#    5812     checkfirst: bool = True,
#    5813 ) -> None:
#    5814     """Create all tables stored in this metadata.
#    5815
#    5816     Conditional by default, will not attempt to recreate tables already
#    (...)
#    5830
#    5831     """
# -> 5832     bind._run_ddl_visitor(
#    5833         ddl.SchemaGenerator, self, checkfirst=checkfirst, tables=tables
#    5834     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:3244, in Engine._run_ddl_visitor(self, visitorcallable, element, **kwargs)
#    3237 def _run_ddl_visitor(
#    3238     self,
#    3239     visitorcallable: Type[Union[SchemaGenerator, SchemaDropper]],
#    3240     element: SchemaItem,
#    3241     **kwargs: Any,
#    3242 ) -> None:
#    3243     with self.begin() as conn:
# -> 3244         conn._run_ddl_visitor(visitorcallable, element, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:2448, in Connection._run_ddl_visitor(self, visitorcallable, element, **kwargs)
#    2436 def _run_ddl_visitor(
#    2437     self,
#    2438     visitorcallable: Type[Union[SchemaGenerator, SchemaDropper]],
#    2439     element: SchemaItem,
#    2440     **kwargs: Any,
#    2441 ) -> None:
#    2442     """run a DDL visitor.
#    2443
#    2444     This method is only here so that the MockConnection can change the
#    2445     options given to the visitor so that "checkfirst" is skipped.
#    2446
#    2447     """
# -> 2448     visitorcallable(self.dialect, self, **kwargs).traverse_single(element)
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\sql\visitors.py:671, in ExternalTraversal.traverse_single(self, obj, **kw)
#     669 meth = getattr(v, "visit_%s" % obj.__visit_name__, None)
#     670 if meth:
# --> 671     return meth(obj, **kw)
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\sql\ddl.py:919, in SchemaGenerator.visit_metadata(self, metadata)
#     917 for table, fkcs in collection:
#     918     if table is not None:
# --> 919         self.traverse_single(
#     920             table,
#     921             create_ok=True,
#     922             include_foreign_key_constraints=fkcs,
#     923             _is_metadata_operation=True,
#     924         )
#     925     else:
#     926         for fkc in fkcs:
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\sql\visitors.py:671, in ExternalTraversal.traverse_single(self, obj, **kw)
#     669 meth = getattr(v, "visit_%s" % obj.__visit_name__, None)
#     670 if meth:
# --> 671     return meth(obj, **kw)
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\sql\ddl.py:957, in SchemaGenerator.visit_table(self, table, create_ok, include_foreign_key_constraints, _is_metadata_operation)
#     948 if not self.dialect.supports_alter:
#     949     # e.g., don't omit any foreign key constraints
#     950     include_foreign_key_constraints = None
#     952 CreateTable(
#     953     table,
#     954     include_foreign_key_constraints=(
#     955         include_foreign_key_constraints
#     956     ),
# --> 957 )._invoke_with(self.connection)
#     959 if hasattr(table, "indexes"):
#     960     for index in table.indexes:
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\sql\ddl.py:315, in ExecutableDDLElement._invoke_with(self, bind)
#     313 def _invoke_with(self, bind):
#     314     if self._should_execute(self.target, bind):
# --> 315         return bind.execute(self)
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1416, in Connection.execute(self, statement, parameters, execution_options)
#    1414     raise exc.ObjectNotExecutableError(statement) from err
#    1415 else:
# -> 1416     return meth(
#    1417         self,
#    1418         distilled_parameters,
#    1419         execution_options or NO_OPTIONS,
#    1420     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\sql\ddl.py:181, in ExecutableDDLElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     178 def _execute_on_connection(
#     179     self, connection, distilled_params, execution_options
#     180 ):
# --> 181     return connection._execute_ddl(
#     182         self, distilled_params, execution_options
#     183     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1528, in Connection._execute_ddl(self, ddl, distilled_parameters, execution_options)
#    1523 dialect = self.dialect
#    1525 compiled = ddl.compile(
#    1526     dialect=dialect, schema_translate_map=schema_translate_map
#    1527 )
# -> 1528 ret = self._execute_context(
#    1529     dialect,
#    1530     dialect.execution_ctx_cls._init_ddl,
#    1531     compiled,
#    1532     None,
#    1533     execution_options,
#    1534     compiled,
#    1535 )
#    1536 if self._has_events or self.engine._has_events:
#    1537     self.dispatch.after_execute(
#    1538         self,
#    1539         ddl,
#    (...)
#    1543         ret,
#    1544     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1848, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1843     return self._exec_insertmany_context(
#    1844         dialect,
#    1845         context,
#    1846     )
#    1847 else:
# -> 1848     return self._exec_single_context(
#    1849         dialect, context, statement, parameters
#    1850     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1988, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1985     result = context._setup_result_proxy()
#    1987 except BaseException as e:
# -> 1988     self._handle_dbapi_exception(
#    1989         e, str_statement, effective_parameters, cursor, context
#    1990     )
#    1992 return result
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:2344, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2342 elif should_wrap:
#    2343     assert sqlalchemy_exception is not None
# -> 2344     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2345 else:
#    2346     assert exc_info[1] is not None
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1969, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1967                 break
#    1968     if not evt_handled:
# -> 1969         self.dialect.do_execute(
#    1970             cursor, str_statement, effective_parameters, context
#    1971         )
#    1973 if self._has_events or self.engine._has_events:
#    1974     self.dispatch.after_cursor_execute(
#    1975         self,
#    1976         cursor,
#    (...)
#    1980         context.executemany,
#    1981     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py:922, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     921 def do_execute(self, cursor, statement, parameters, context=None):
# --> 922     cursor.execute(statement, parameters)
#
# ProgrammingError: (psycopg2.errors.InvalidForeignKey) there is no unique constraint matching given keys for referenced table "traffic_data"
#
# [SQL:
# CREATE TABLE domain_location (
# 	location_id SERIAL NOT NULL,
# 	"SourceCommonName" VARCHAR(255),
# 	location VARCHAR(2),
# 	traffic_data_domain VARCHAR(255),
# 	PRIMARY KEY (location_id),
# 	FOREIGN KEY(traffic_data_domain) REFERENCES traffic_data ("Domain")
# )
#
# ]
# (Background on this error at: https://sqlalche.me/e/20/f405)
