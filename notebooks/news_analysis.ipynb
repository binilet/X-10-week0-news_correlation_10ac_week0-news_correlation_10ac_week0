# %%
import sys, os
if os.path.abspath("..") not in sys.path:
    sys.path.insert(0, os.path.abspath(".."))

import matplotlib.pyplot as plt

from src.utils import find_top_websites
from src.loader import NewsDataLoader

loader = NewsDataLoader()
news_data = loader.load_data('../data/data.csv/rating.csv')

top_websites = find_top_websites(news_data)
print(top_websites)

#ploting the date ;;; hope this works
plt.figure(figsize=(10,6))
top_websites.plot(kind='bar',color='blue')
plt.title('Top websites with the largest count of news articles')
plt.xlabel('Website Domain')
plt.ylabel('No of News Articles')
plt.xticks(rotation=45,ha='right')
plt.tight_layout()
plt.show()
# Out:
# domain
# www.etfdailynews.com            16746
# www.globenewswire.com            5423
# economictimes.indiatimes.com     5310
# www.globalsecurity.org           3119
# www.forbes.com                   2784
# timesofindia.indiatimes.com      2194
# abcnews.go.com                   2058
# www.businessinsider.com          2034
# www.bbc.co.uk                    2032
# punchng.com                      1800
# Name: count, dtype: int64

# %%
import sys, os
if os.path.abspath("..") not in sys.path:
    sys.path.insert(0, os.path.abspath(".."))

import matplotlib.pyplot as plt

from src.utils import find_high_traffic_websites
from src.loader import NewsDataLoader

loader = NewsDataLoader()
news_data = loader.load_data('../data/traffic.csv')

top_traffic_websites = find_high_traffic_websites(news_data)
print(top_traffic_websites)

plt.figure(figsize=(10,6))
top_traffic_websites.plot(kind='line',marker='o',color='green',linestyle='-')
plt.title('Top websites with the highest traffic')
plt.xlabel('website')
plt.ylabel('total ips')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
#    GlobalRank  TldRank        Domain  TLD  RefSubNets   RefIPs    IDN_Domain  \
# 0           1        1    google.com  com      471274  2151358    google.com
# 1           2        2  facebook.com  com      465424  2250631  facebook.com
#
#   IDN_TLD  PrevGlobalRank  PrevTldRank  PrevRefSubNets  PrevRefIPs
# 0     com               1            1          471248     2147402
# 1     com               2            2          465297     2247135
# Domain
# facebook.com            2250631
# google.com              2151358
# youtube.com             1852995
# twitter.com             1757127
# instagram.com           1598085
# linkedin.com            1319082
# googletagmanager.com     863843
# wordpress.org            835948
# wikipedia.org            831384
# apple.com                804726
# Name: RefIPs, dtype: int64
